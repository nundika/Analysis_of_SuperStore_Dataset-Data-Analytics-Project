# %%
# Importing libraries
import pandas as pd
import numpy as np

# %%
# Importing the dataset
df = pd.read_csv("Analysis of Super Store - DA.csv")
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
# Shape of the dataset
df.shape
# Out:
# (9994, 13)

# %% [markdown]
#  **checking information about dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# **Read the columns or Features of the dataset**

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# #**DATASET INFO**
#
# DataFrame.count :
# Count number of non-NA/null observations.
#
# DataFrame.max :
# Maximum of the values in the object.
#
# DataFrame.min :
# Minimum of the values in the object.
#
# DataFrame.mean :
# Mean of the values.
#
# DataFrame.std :
# Standard deviation of the observations.
#
# DataFrame.select_dtypes :
# Subset of a DataFrame including/excluding columns based on their dtype.

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
#  **NULL VALUES**

# %%
df.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# **Read the Duplicate value**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **FEATURES OF DATASET**

# %%
df_cat = df[[ 'Ship Mode','Segment', 'Country', 'City', 'State', 'Region',
             'Category', 'Sub-Category']]

# %%
df_cat.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category
# 0  South        Furniture    Bookcases
# 1  South        Furniture       Chairs
# 2   West  Office Supplies       Labels
# 3  South        Furniture       Tables
# 4  South  Office Supplies      Storage

# %% [markdown]
# **UNIQUE VALUES**

# %%
# unique values
for feature in df_cat.columns:
    print(feature,':',df[feature].nunique())
# Out:
# Ship Mode : 4
# Segment : 3
# Country : 1
# City : 531
# State : 49
# Region : 4
# Category : 3
# Sub-Category : 17

# %% [markdown]
# # **EDA - EXPLORATORY DATA ANALYSIS**

# %%
# Display first 5 rows
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# Display last 5 rows
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# **What are the top selling products in the superstore?**

# %%
# Group the data by Category and sum up the sales
category_group = df.groupby(["Category"]).sum()["Sales"]
category_group.head()
# Out:
# <ipython-input-22-0ab6899acdf5>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   category_group = df.groupby(["Category"]).sum()["Sales"]
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
top_category_sales = category_group.sort_values(ascending=False)
top_category_sales
# Out:
# Category
# Technology         836154.0330
# Furniture          741999.7953
# Office Supplies    719047.0320
# Name: Sales, dtype: float64

# %% [markdown]
# **Products with most sales**

# %%
# Group the data by Subcategory and sum up the sales
subcategory_group = df.groupby(["Sub-Category"]).sum()["Sales"]
subcategory_group.head()
# Out:
# <ipython-input-25-5e763e04dbbd>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   subcategory_group = df.groupby(["Sub-Category"]).sum()["Sales"]
# Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27118.7920
# Binders        203412.7330
# Bookcases      114879.9963
# Name: Sales, dtype: float64

# %%
# Sort the data by sales in descending order
top_subcategory_sales = subcategory_group.sort_values(ascending=False)
top5_subcategory_sales = pd.DataFrame(top_subcategory_sales.head())
top_subcategory_sales
# Out:
# Sub-Category
# Phones         330007.0540
# Chairs         328449.1030
# Storage        223843.6080
# Tables         206965.5320
# Binders        203412.7330
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Furnishings     91705.1640
# Paper           78479.2060
# Supplies        46673.5380
# Art             27118.7920
# Envelopes       16476.4020
# Labels          12486.3120
# Fasteners        3024.2800
# Name: Sales, dtype: float64

# %% [markdown]
# **Plotting Top 5 selling products in superstore**

# %%
# Importing matplotlib and seaborn library for plotting :
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
top5_subcategory_sales.plot(kind="bar")

# Add a title to the plot
plt.title("Top 5 Selling Product-type")

# Add labels to the x and y axes
plt.xlabel("Product Type")
plt.ylabel("Total Sales")

# Show the plot
plt.show()

# %% [markdown]
# **Most profitable products**

# %%
product_profit = df.groupby(["Sub-Category"]).sum()["Profit"]

top_profit = product_profit.sort_values(ascending=False)

top5_profit =pd.DataFrame(top_profit.head())
top_profit
# Out:
# <ipython-input-41-da50156fa128>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   product_profit = df.groupby(["Sub-Category"]).sum()["Profit"]
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          34053.5693
# Binders        30221.7633
# Chairs         26590.1663
# Storage        21278.8264
# Appliances     18138.0054
# Furnishings    13059.1436
# Envelopes       6964.1767
# Art             6527.7870
# Labels          5546.2540
# Machines        3384.7569
# Fasteners        949.5182
# Supplies       -1189.0995
# Bookcases      -3472.5560
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
#Top 5 Profitting products
top5_profit.plot(kind="bar")

plt.title("Top 5 most profitting sales")

plt.xlabel("Product Type")
plt.ylabel("Profit")

plt.show()

# %% [markdown]
# **Are the top-selling products the most profitable?**

# %%
top5_profit.index == top5_subcategory_sales.index
# Out:
# array([False, False, False, False,  True])

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))

# Plot the top 5 selling products in the first column
top5_subcategory_sales.plot(kind="bar", y="Sales", ax=ax1)

# Set the title for the first plot
ax1.set_title("Top 5 Selling Products")

# Plot the top 5 profit products in the second column
top5_profit.plot(kind="bar", y="Profit", ax=ax2)

# Set the title for the second plot
ax2.set_title("Top 5 Profit Products")

# Show the plot
plt.show()

# %%
list(top5_profit.index)
# Out:
# ['Copiers', 'Phones', 'Accessories', 'Paper', 'Binders']

# %%
list(top5_subcategory_sales.index)
# Out:
# ['Phones', 'Chairs', 'Storage', 'Tables', 'Binders']

# %%
df.Region.value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
# Filter data according to product phone
product = df[df["Sub-Category"] == "Phones"]

# Group the data by Region
product_region_sale = product.groupby(["Region"]).mean()[["Sales", "Profit"]]

# Ploting
product_region_sale.plot(kind="bar")

plt.show()
# Out:
# <ipython-input-54-dc3911ba3651>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   product_region_sale = product.groupby(["Region"]).mean()[["Sales", "Profit"]]

# %%
# Filter data according to product binders
product = df[df["Sub-Category"] == "Binders"]

# Group the data by Region
product_region_sale = product.groupby(["Region"]).mean()[["Sales", "Profit"]]

# Ploting
product_region_sale.plot(kind="bar")

plt.show()
# Out:
# <ipython-input-55-e931ea2583b8>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   product_region_sale = product.groupby(["Region"]).mean()[["Sales", "Profit"]]

# %%
product = df[(df["Sub-Category"] == "Phones") & (df["Region"] == "Central")]
product.head()
# Out:
#           Ship Mode      Segment        Country        City      State  \
# 35      First Class    Corporate  United States  Richardson      Texas
# 40   Standard Class  Home Office  United States     Houston      Texas
# 41   Standard Class    Corporate  United States  Naperville   Illinois
# 147  Standard Class    Corporate  United States    Franklin  Wisconsin
# 148  Standard Class    Corporate  United States    Franklin  Wisconsin
#
#      Postal Code   Region    Category Sub-Category     Sales  Quantity  \
# 35         75080  Central  Technology       Phones  1097.544         7
# 40         77041  Central  Technology       Phones   371.168         4
# 41         60540  Central  Technology       Phones   147.168         4
# 147        53132  Central  Technology       Phones   384.450        11
# 148        53132  Central  Technology       Phones   149.970         3
#
#      Discount    Profit
# 35        0.2  123.4737
# 40        0.2   41.7564
# 41        0.2   16.5564
# ...

# %% [markdown]
# **Products offering highest discounts?**

# %%
product_discount = df.groupby(["Sub-Category"]).sum()["Discount"]

top_discount = product_discount.sort_values(ascending=False)

top5_discount =pd.DataFrame(top_discount.head())
top5_discount
# Out:
# <ipython-input-71-0a2eebc12b69>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   product_discount = df.groupby(["Sub-Category"]).sum()["Discount"]
#               Discount
# Sub-Category
# Binders          567.0
# Phones           137.4
# Furnishings      132.4
# Chairs           105.0
# Paper            102.6

# %% [markdown]
# **Are the products with most disconts profitable? **

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))

# Plot the top 5 profitable products in the first column
top5_profit.plot(kind="bar", y="Profit", ax=ax1)

# Set the title for the first plot
ax1.set_title("Top 5 Profitable Products")

# Plot the top 5 discounted products in the second column
top5_discount.plot(kind="bar", y="Discount", ax=ax2)

# Set the title for the second plot
ax2.set_title("Top 5 Discounted products")

# Show the plot
plt.show()

# %% [markdown]
# **Geographical Analytics?**

# %%
#list out abd view every location column
df_places = df[['Country','City','State','Region','Postal Code']]
df_places.head()
# Out:
#          Country             City       State Region  Postal Code
# 0  United States        Henderson    Kentucky  South        42420
# 1  United States        Henderson    Kentucky  South        42420
# 2  United States      Los Angeles  California   West        90036
# 3  United States  Fort Lauderdale     Florida  South        33311
# 4  United States  Fort Lauderdale     Florida  South        33311

# %%
#check for uniqu components
for place in df_places.columns:
    print(place,':',df_places[place].nunique())
# Out:
# Country : 1
# City : 531
# State : 49
# Region : 4
# Postal Code : 631

# %% [markdown]
# Since there is only 1 country ,we dont need Country column for further analytics

# %%
df_places = df[['City','State','Region','Sales','Profit','Postal Code']]
df_places.head()
# Out:
#               City       State Region     Sales    Profit  Postal Code
# 0        Henderson    Kentucky  South  261.9600   41.9136        42420
# 1        Henderson    Kentucky  South  731.9400  219.5820        42420
# 2      Los Angeles  California   West   14.6200    6.8714        90036
# 3  Fort Lauderdale     Florida  South  957.5775 -383.0310        33311
# 4  Fort Lauderdale     Florida  South   22.3680    2.5164        33311

# %%
# Group the data by Region and calculate the total sales for each
region_sales = df_places.groupby(['Region'], as_index=False).sum()
region_sales.sort_values(by='Sales', ascending=False, inplace=True)

# Total sales by region
plt.bar(region_sales['Region'], region_sales['Sales'])
plt.xlabel("Region")
plt.ylabel("Sales")
plt.title("Sales in Region")
plt.show()
region_sales
# Out:
# <ipython-input-94-32ce6876870e>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   region_sales = df_places.groupby(['Region'], as_index=False).sum()
#     Region        Sales       Profit
# 3     West  725457.8245  108418.4489
# 1     East  678781.2400   91522.7800
# 0  Central  501239.8908   39706.3625
# 2    South  391721.9050   46749.4303

# %%
# Group the data by Region and calculate the total profit for each
region_profit = df_places.groupby(['Region'], as_index=False).sum()
region_profit.sort_values(by='Profit', ascending=False, inplace=True)

# Profit in each region
plt.bar(region_profit['Region'], region_profit['Profit'])
plt.xlabel("Region")
plt.ylabel("Profit")
plt.title("Profit in Region")
plt.show()
region_profit
# Out:
# <ipython-input-95-94c04c04b3a0>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   region_profit = df_places.groupby(['Region'], as_index=False).sum()
#     Region        Sales       Profit
# 3     West  725457.8245  108418.4489
# 1     East  678781.2400   91522.7800
# 2    South  391721.9050   46749.4303
# 0  Central  501239.8908   39706.3625

# %%
state_sales = df_places.groupby(['State'], as_index=False).sum()
state_sales.sort_values(by='Sales', ascending=False, inplace=True)

plt.bar(state_sales['State'], state_sales['Sales'])
plt.xlabel("State")
plt.ylabel("Sales")
plt.title("State Sales")
plt.xticks(rotation=90)

plt.show()
state_sales.head()
# Out:
# <ipython-input-100-d145748461de>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   state_sales = df_places.groupby(['State'], as_index=False).sum()
#            State        Sales      Profit
# 3     California  457687.6315  76381.3871
# 30      New York  310876.2710  74038.5486
# 41         Texas  170188.0458 -25729.3563
# 45    Washington  138641.2700  33402.6517
# 36  Pennsylvania  116511.9140 -15559.9603

# %%
state_profit = df_places.groupby(['State'], as_index=False).sum()
state_profit.sort_values(by='Profit', ascending=False, inplace=True)


plt.bar(state_profit['State'], state_profit['Profit'])
plt.xlabel("State")
plt.ylabel("Profit")
plt.title("State Profit")
plt.xticks(rotation=90)

plt.show()
state_profit.head()
# Out:
# <ipython-input-101-d725ae158134>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   state_profit = df_places.groupby(['State'], as_index=False).sum()
#          State        Sales      Profit
# 3   California  457687.6315  76381.3871
# 30    New York  310876.2710  74038.5486
# 45  Washington  138641.2700  33402.6517
# 20    Michigan   76269.6140  24463.1876
# 44    Virginia   70636.7200  18597.9504

# %%
city_sales = df_places.groupby('City', as_index=False).sum()
city_sales.sort_values(by='Sales', ascending=False, inplace=True)

# Select the top 5 cities
top5_cities_sales = city_sales.head()

plt.bar(top5_cities_sales['City'], top5_cities_sales['Sales'])
plt.xlabel("City")
plt.ylabel("Sales")
plt.title("Top Cities by Sales")

plt.show()
top5_cities_sales
# Out:
# <ipython-input-107-c6c7c0b4a679>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   city_sales = df_places.groupby('City', as_index=False).sum()
#               City       Sales      Profit  Postal Code
# 329  New York City  256368.161  62036.9837      9168909
# 266    Los Angeles  175851.341  30440.7579     67252887
# 452        Seattle  119540.742  29156.0967     41989758
# 438  San Francisco  112669.092  17507.3854     47998395
# 374   Philadelphia  109077.013 -13837.7674     10275302

# %%
city_profit = df_places.groupby('City', as_index=False).sum()
city_profit.sort_values(by='Profit', ascending=False, inplace=True)

# Select the top 5 cities
top5_cities_profit =city_profit.head()

plt.bar(top5_cities_profit['City'], top5_cities_profit['Profit'])
plt.xlabel("City")
plt.ylabel("Profit")
plt.title("Top Cities by Profit")

plt.show()
top5_cities_profit
# Out:
# <ipython-input-108-92eb298264d7>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   city_profit = df_places.groupby('City', as_index=False).sum()
#               City       Sales      Profit  Postal Code
# 329  New York City  256368.161  62036.9837      9168909
# 266    Los Angeles  175851.341  30440.7579     67252887
# 452        Seattle  119540.742  29156.0967     41989758
# 438  San Francisco  112669.092  17507.3854     47998395
# 123        Detroit   42446.944  13181.7908      5545741

# %%
area_sales = df_places.groupby('Postal Code', as_index=False).sum()
area_sales.sort_values(by='Sales', ascending=False, inplace=True)

# Select the top 5 areas
top5_areas_sales = area_sales.head()
mylabels=(top5_areas_sales['Postal Code'])
y=np.array(top5_areas_sales['Sales'])
plt.pie(y, labels = mylabels)

plt.title("Top Areas by Sales")

plt.show()
top5_areas_sales
# Out:
# <ipython-input-117-cea3e7cdb175>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   area_sales = df_places.groupby('Postal Code', as_index=False).sum()
#      Postal Code      Sales      Profit
# 54         10024  78697.182  21653.7248
# 55         10035  77357.885  16533.8669
# 52         10009  54761.496  13697.0019
# 578        94122  52667.467   7712.5958
# 53         10011  45551.598  10152.3901

# %%
area_profit = df_places.groupby('Postal Code', as_index=False).sum()
area_profit.sort_values(by='Profit', ascending=False, inplace=True)

# Select the top 5 areas
top5_areas_profit = area_profit.head()
mylabels=(top5_areas_profit['Postal Code'])
y=np.array(top5_areas_profit['Profit'])
plt.pie(y, labels = mylabels)

plt.title("Top Areas by Profit")

plt.show()
top5_areas_profit
# Out:
# <ipython-input-125-2dd80e636cb2>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   area_profit = df_places.groupby('Postal Code', as_index=False).sum()
#      Postal Code      Sales      Profit
# 54         10024  78697.182  21653.7248
# 55         10035  77357.885  16533.8669
# 52         10009  54761.496  13697.0019
# 621        98115  41160.908  13303.8755
# 53         10011  45551.598  10152.3901

# %% [markdown]
# **Region results**
#
# *  **Region :** [West]
# *  **State :** [california, New York]
# *  **Cities:** [New York City, Los Angeles, Seattle, San Francisco, Detroit]
# *  **Areas:** [10024,10035,1009]

# %%
df.Discount.value_counts()
# Out:
# 0.00    4798
# 0.20    3657
# 0.70     418
# 0.80     300
# 0.30     227
# 0.40     206
# 0.60     138
# 0.10      94
# 0.50      66
# 0.15      52
# 0.32      27
# 0.45      11
# Name: Discount, dtype: int64

# %%
# Group the data by the discount and compute the average sales
discount_sales = df.groupby(["Discount"]).mean()[["Sales"]]

ax = discount_sales.plot(kind="bar")

ax.set_ylabel("Sales")

plt.show()
discount_sales
# Out:
# <ipython-input-132-fd1ac1205af4>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   discount_sales = df.groupby(["Discount"]).mean()[["Sales"]]
#                Sales
# Discount
# 0.00      226.742074
# 0.10      578.397351
# 0.15      529.971567
# 0.20      209.076940
# 0.30      454.742974
# 0.32      536.794770
# 0.40      565.134874
# 0.45      498.634000
# 0.50      892.705152
# 0.60       48.150000
# 0.70       97.177708
# 0.80       56.545853

# %%
# Create a scatter plot between sales and discounts
plt.figure(figsize=(15,6))
plt.scatter(df['Sales'],df['Discount'])
plt.ylabel("Discount")
plt.xlabel("Sales")
plt.show()

# %%
# Group the data by the discount and profit
plt.figure(figsize=(15,6))
plt.scatter(df['Profit'],df['Discount'])
plt.ylabel("Discount")
plt.xlabel("Profit")
plt.show()

# %% [markdown]
# **DIscount Results**
#
#
# *   Highest Sales - Discount=50% *But it causes more losses*
# *   Best Discount - 10% to 20%
#
# Reason - ( Causes Profit and also 2nd and 3rd bestseller after 0% discount )

# %%
df['Profit Margin'] = df['Profit'] / df['Sales']

# Group category and data and calculate the average profit margin for each
avg_profit_margin = df.groupby('Category')['Profit Margin'].mean()
plt.figure(figsize=(15,6))
avg_profit_margin.plot(kind='bar')

plt.title("Average Profit Margin of category")
plt.xlabel("Category")
plt.ylabel("Average Profit Margin")
plt.xticks(rotation=0)
plt.show()

avg_profit_margin
# Out:
# Category
# Furniture          0.038784
# Office Supplies    0.138030
# Technology         0.156138
# Name: Profit Margin, dtype: float64

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit  Profit Margin
# 0      0.00   41.9136         0.1600
# ...

# %% [markdown]
# **Relation between Ship Mode and Segment**

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
#Related Sales
table= df.pivot_table(index='Segment', columns='Ship Mode', values='Sales', aggfunc='sum')
table.plot(kind='bar')
plt.xticks(rotation=0)
plt.show()

table
# Out:
# Ship Mode    First Class   Same Day  Second Class  Standard Class
# Segment
# Consumer     159168.9650  60596.359   231498.9496     710137.0714
# Corporate    105858.4699  45121.323   146126.0388     409040.5351
# Home Office   86400.9880  22645.443    81568.5810     239038.1365

# %%
#Related Profit
pivot_table = df.pivot_table(index='Segment', columns='Ship Mode', values='Profit', aggfunc='sum')
pivot_table.plot(kind='bar')
plt.xticks(rotation=0)
plt.show()

table
# Out:
# Ship Mode    First Class   Same Day  Second Class  Standard Class
# Segment
# Consumer     159168.9650  60596.359   231498.9496     710137.0714
# Corporate    105858.4699  45121.323   146126.0388     409040.5351
# Home Office   86400.9880  22645.443    81568.5810     239038.1365

# %% [markdown]
# **Relation of Product quantity to Ship Mode and Segment**

# %%
df['Quantity'].value_counts()
# Out:
# 3     2409
# 2     2402
# 5     1230
# 4     1191
# 1      899
# 7      606
# 6      572
# 9      258
# 8      257
# 10      57
# 11      34
# 14      29
# 13      27
# 12      23
# Name: Quantity, dtype: int64

# %%
#Related Sales
table= df.pivot_table(index='Segment', columns='Quantity', values='Sales', aggfunc='sum')
table.plot(kind='bar')
plt.xticks(rotation=0)
plt.show()

table
# Out:
# Quantity             1            2            3            4            5   \
# Segment
# Consumer     27060.9409  145326.4684  218331.6111  171472.5852  216480.1065
# Corporate    15201.8972   90716.0496  128120.8929   80542.7476  140870.4050
# Home Office  10989.0964   53048.9618   75608.0967   71655.6616   58311.1850
#
# Quantity             6            7          8           9          10  \
# Segment
# Consumer     92880.5820  112396.1188  60388.856  59129.0811   6932.640
# Corporate    57946.5834   93850.3321  36893.160  38345.6430  12623.294
# Home Office  56295.1560   33661.9150  20478.160  31030.8660   4500.730
#
# Quantity           11        12         13        14
# Segment
# Consumer     6462.610  8242.632  28467.361  7829.752
# Corporate    4081.968   681.624   3418.766  2853.004
# Home Office  5227.904  5944.152    452.062  2449.202

# %%
#Related Sales
table= df.pivot_table(index='Ship Mode', columns='Quantity', values='Sales', aggfunc='sum')
table.plot(kind='bar')
plt.xticks(rotation=0)
plt.show()

table
# Out:
# Quantity                1            2            3            4   \
# Ship Mode
# First Class      7522.1004   60363.3548   63488.3037   62330.5696
# Same Day         3511.1600   17128.7540   20046.0870   30029.1920
# Second Class    11924.5714   49765.9608   87206.1870   55615.3336
# Standard Class  30294.1027  161833.4102  251320.0230  175695.8992
#
# Quantity                 5            6            7          8           9   \
# Ship Mode
# First Class      53883.5120   27784.0644   31436.3420  22730.904  11330.7120
# Same Day         25334.9450    6800.7480   15132.8100   4321.616   3749.7600
# Second Class     93509.7200   38471.9220   42494.1930  19445.088  35235.5616
# Standard Class  242933.5195  134065.5870  150845.0209  71262.568  78189.5565
#
# Quantity               10        11        12         13        14
# Ship Mode
# First Class      3190.860  4694.162  1753.464    881.686    38.388
# Same Day          766.920   421.245       NaN        NaN  1119.888
# ...

# %% [markdown]
# **RESULTS**
#
#
# *   Category with highest avg profit margin - **Technology** (*0.156*)
# *   Most active sales segment - **Cuonsumer**
# *   Most used Ship mode - **Standard Class**

# %% [markdown]
# Most Sales and Profit is generated by **Consumer** segment using **Standard class** shipment

# %% [markdown]
# #**DATA VISUALIZATION USING TABLEAU**
# src - YT *TechNikes*
# ![image.png](data:image/png;base64,...)
